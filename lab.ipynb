# %%
import pandas as pd
from pipelines.train import ModelTrainer
from pipelines.analyze import DataAnalyzer

# %%
df = pd.read_csv('data/insurance.csv')

# %%
df.head()

# %%
analysis = DataAnalyzer(df, target='charges')

# %%
analysis.analyze()

# %%
trainer = ModelTrainer(df, target='charges')

# %%
trainer.train()
